# %%
import pandas as pd
iris = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data")
print(type(iris))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df = iris.copy()
df.head(3)
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa

# %%
df.columns
df.columns = ['sl','sw','pl','pw','flower_type']
print(df.head(3))
# Out:
#     sl   sw   pl   pw  flower_type
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa

# %%
print(df.shape)
print(df.dtypes)
# Out:
# (149, 5)
# sl             float64
# sw             float64
# pl             float64
# pw             float64
# flower_type     object
# dtype: object

# %%
print(df.isnull().sum())
df.describe()
# Out:
# sl             0
# sw             0
# pl             0
# pw             0
# flower_type    0
# dtype: int64
#                sl          sw          pl          pw
# count  149.000000  149.000000  149.000000  149.000000
# mean     5.848322    3.051007    3.774497    1.205369
# std      0.828594    0.433499    1.759651    0.761292
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
print(df['sl'])
df.sl
# Out:
# 0      4.9
# 1      4.7
# 2      4.6
# 3      5.0
# 4      5.4
#       ...
# 144    6.7
# 145    6.3
# 146    6.5
# 147    6.2
# 148    5.9
# Name: sl, Length: 149, dtype: float64
# 0      4.9
# 1      4.7
# 2      4.6
# 3      5.0
# 4      5.4
#       ...
# 144    6.7
# 145    6.3
# 146    6.5
# 147    6.2
# 148    5.9
# Name: sl, Length: 149, dtype: float64

# %%
df.iloc[51:100,4:5]
# Out:
#         flower_type
# 51  Iris-versicolor
# 52  Iris-versicolor
# 53  Iris-versicolor
# 54  Iris-versicolor
# 55  Iris-versicolor
# 56  Iris-versicolor
# 57  Iris-versicolor
# 58  Iris-versicolor
# 59  Iris-versicolor
# 60  Iris-versicolor
# 61  Iris-versicolor
# 62  Iris-versicolor
# 63  Iris-versicolor
# 64  Iris-versicolor
# 65  Iris-versicolor
# 66  Iris-versicolor
# 67  Iris-versicolor
# 68  Iris-versicolor
# 69  Iris-versicolor
# 70  Iris-versicolor
# 71  Iris-versicolor
# 72  Iris-versicolor
# 73  Iris-versicolor
# 74  Iris-versicolor
# 75  Iris-versicolor
# 76  Iris-versicolor
# 77  Iris-versicolor
# 78  Iris-versicolor
# 79  Iris-versicolor
# 80  Iris-versicolor
# 81  Iris-versicolor
# 82  Iris-versicolor
# 83  Iris-versicolor
# 84  Iris-versicolor
# 85  Iris-versicolor
# 86  Iris-versicolor
# 87  Iris-versicolor
# 88  Iris-versicolor
# 89  Iris-versicolor
# 90  Iris-versicolor
# 91  Iris-versicolor
# 92  Iris-versicolor
# 93  Iris-versicolor
# 94  Iris-versicolor
# ...

# %%
df.drop(0)  
df.head()

df.drop(0,inplace=True)
df.head()
# Out:
#     sl   sw   pl   pw  flower_type
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa
# 5  4.6  3.4  1.4  0.3  Iris-setosa

# %%
df[df.flower_type=='Iris-setosa'].describe()
df.loc[0]=[4.9,3.0,1.4,0.2,'Iris-setosa']
print(df.tail())
df[df.flower_type=='Iris-setosa'].describe()
# Out:
#       sl   sw   pl   pw     flower_type
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
# 0    4.9  3.0  1.4  0.2     Iris-setosa
#               sl         sw         pl         pw
# count  49.000000  49.000000  49.000000  49.000000
# mean    5.004082   3.416327   1.465306   0.244898
# std     0.355879   0.384787   0.175061   0.108130
# min     4.300000   2.300000   1.000000   0.100000
# 25%     4.800000   3.100000   1.400000   0.200000
# 50%     5.000000   3.400000   1.500000   0.200000
# 75%     5.200000   3.700000   1.600000   0.300000
# max     5.800000   4.400000   1.900000   0.600000

# %%
import pandas as pd
df = pd.read_csv("https://gist.githubusercontent.com/netj/8836201/raw/6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv")
print(df.shape)
# Out:
# (150, 5)

# %%
df.variety.unique()
arr=df[df.variety=='Setosa']
df.index[0]
# Out:
# 0

# %%
df[((df["variety"]=='Virginica') & (df['petal.length']>1.5))]
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 100           6.3          3.3           6.0          2.5  Virginica
# 101           5.8          2.7           5.1          1.9  Virginica
# 102           7.1          3.0           5.9          2.1  Virginica
# 103           6.3          2.9           5.6          1.8  Virginica
# 104           6.5          3.0           5.8          2.2  Virginica
# 105           7.6          3.0           6.6          2.1  Virginica
# 106           4.9          2.5           4.5          1.7  Virginica
# 107           7.3          2.9           6.3          1.8  Virginica
# 108           6.7          2.5           5.8          1.8  Virginica
# 109           7.2          3.6           6.1          2.5  Virginica
# 110           6.5          3.2           5.1          2.0  Virginica
# 111           6.4          2.7           5.3          1.9  Virginica
# 112           6.8          3.0           5.5          2.1  Virginica
# ...

# %%
df.head()
df.drop('sepal.length',axis=1)
del df['sepal.length']
# Out:
# ------------------------------
# KeyErrorTraceback (most recent call last)
# <ipython-input-72-6320e843f3a7> in <module>
#       1 df.head()
# ----> 2 df.drop('sepal.length',axis=1)
#       3 del df['sepal.length']
#       4 print(df)
#
# D:\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# D:\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# D:\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %%
df['diff']=df['sepal.width']-df['petal.length']
print(df.tail())
# Out:
#      sepal.width  petal.length  petal.width    variety  diff
# 145          3.0           5.2          2.3  Virginica  -2.2
# 146          2.5           5.0          1.9  Virginica  -2.5
# 147          3.0           5.2          2.0  Virginica  -2.2
# 148          3.4           5.4          2.3  Virginica  -2.0
# 149          3.0           5.1          1.8  Virginica  -2.1

# %%
import pandas as pd
col_name=['sepal_length','sepal_width','petal_length','petal_width','type']
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data",names=col_name)
arr = df['type'].unique()
for i in arr:
      print(df[df['type']==i].describe())
#     v1=df[df['type']==i][col_name[0]]
#     v2=df[df['type']==i][col_name[1]]
#     v3=df[df['type']==i][col_name[2]]
#     v4=df[df['type']==i][col_name[3]]
#     print(v1.min(),v2.min(),v3.min(),v4.min())
#     print(v1.max(),v2.max(),v3.max(),v4.max())
#     print(round(v1.mean(),2),round(v2.mean(),2),round(v3.mean(),2),round(v4.mean(),2))
   # print("%.2f %.2f"%v1.min() %v2.min())
    
    #print(df[df['type']==i].i.max())
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000     50.00000
# mean        5.00600     3.418000      1.464000      0.24400
# std         0.35249     0.381024      0.173511      0.10721
# min         4.30000     2.300000      1.000000      0.10000
# 25%         4.80000     3.125000      1.400000      0.20000
# 50%         5.00000     3.400000      1.500000      0.20000
# 75%         5.20000     3.675000      1.575000      0.30000
# max         5.80000     4.400000      1.900000      0.60000
#        sepal_length  sepal_width  petal_length  petal_width
# count     50.000000    50.000000     50.000000    50.000000
# mean       5.936000     2.770000      4.260000     1.326000
# std        0.516171     0.313798      0.469911     0.197753
# min        4.900000     2.000000      3.000000     1.000000
# 25%        5.600000     2.525000      4.000000     1.200000
# 50%        5.900000     2.800000      4.350000     1.300000
# ...
